# %% [markdown]
# <a href="https://colab.research.google.com/github/Shailja12326646/STARTING_WITH_NLP/blob/main/Resume_Parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr
# !pip install imutils
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 20.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pdf2image
# !apt-get install poppler-utils
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.12 [186 kB]
# Fetched 186 kB in 1s (203 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.12_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.12) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.12) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 56.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 84.9 MB/s eta 0:00:00
# ...

# %%
import pdfplumber

text = ""
with pdfplumber.open("/content/LPUCV24.pdf") as pdf:
    for page in pdf.pages:
        text += page.extract_text() + "\n"

print(text)
# Out:
# Ashish Garud
# LinkedIn: https://www.linkedin.com/in/ashishgarud/ Email: ashishgarud539@gmail.com
# GitHub: https://github.com/ashishgarud Mobile: +91-9067557760
# SKILLS
# Languages: Java, C/C++, HTML, CSS, JavaScript, PL/SQL
# Frameworks: MERN Stack, Bootstrap, Flask, Streamlit
# Tools/Platforms: MySQL, MongoDB, Firebase, Git, Docker, Hadoop, Spark, Power BI, Tableau
# Soft Skills: Problem-Solving, Team Collaboration, Project Management, Adaptability, Analytical Thinking
# INTERNSHIP
# Edunet AICTE - Virtual Internship | Link Jun’ 25-Aug’ 25
# Python Developer Intern
# • Established metrics-driven applications with focus on intelligence pipeline debugging and optimization
# • Implemented input validation and anomaly detection techniques for comprehension quality assurance
# • Built engaging statistics dashboards and visualizations applying Python libraries
# • Integrated ML models via APIs and operationalized security and validation protocols
# ...

# %%
text=text.lower()

# %%
text
# Out:
# "ashish garud\nlinkedin: https://www.linkedin.com/in/ashishgarud/ email: ashishgarud539@gmail.com\ngithub: https://github.com/ashishgarud mobile: +91-9067557760\nskills\nlanguages: java, c/c++, html, css, javascript, pl/sql\nframeworks: mern stack, bootstrap, flask, streamlit\ntools/platforms: mysql, mongodb, firebase, git, docker, hadoop, spark, power bi, tableau\nsoft skills: problem-solving, team collaboration, project management, adaptability, analytical thinking\ninternship\nedunet aicte - virtual internship | link jun’ 25-aug’ 25\npython developer intern\n• established metrics-driven applications with focus on intelligence pipeline debugging and optimization\n• implemented input validation and anomaly detection techniques for comprehension quality assurance\n• built engaging statistics dashboards and visualizations applying python libraries\n• integrated ml models via apis and operationalized security and validation protocols\n• tech stacks used: python, streamlit, flask, ml ap
# ...

# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
tokenizer = AutoTokenizer.from_pretrained(
    "dbmdz/bert-large-cased-finetuned-conll03-english"
)
model = AutoModelForTokenClassification.from_pretrained(
    "dbmdz/bert-large-cased-finetuned-conll03-english"
)
ner = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")
print(ner(text))
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# []

# %%
# !pip install gliner
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.9 MB/s eta 0:00:00
# ...

# %%
from gliner import GLiNER
model = GLiNER.from_pretrained("urchade/gliner_small-v2.1")
labels = [
    "person",
    "email",
    "github",
    "skill",
    "job title",
    "college",
    "degree",
    "gpa",
    "experience"
]
# 4. Predict
entities = model.predict_entities(text, labels)
# 5. Print results
for entity in entities:
    print(f"{entity['text']} => {entity['label']}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/611M [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# gliner_config.json:   0%|          | 0.00/477 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# ...
